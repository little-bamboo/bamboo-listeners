# %%
import scrapy
import requests
from scrapy.http import TextResponse
import json

r = requests.get('https://secure.seattletimes.com/accountcenter/login')
response = TextResponse(r.url, body=r.text, encoding='utf-8')

# %%
# print (response.body)

# %%
# Obtain the response from the login

login = scrapy.FormRequest.from_response(
            response,
            formdata={'username': 'briansc@gmail.com', 'password': 'thomas7'}
        )

print login.body
# Out:
# rememberme=1&return_url=&form_url=&username=briansc%40gmail.com&password=thomas7

# %%
r = requests.get('http://vendorapi.seattletimes.com/st/proxy-api/v1.0/st_search/search?query=the&startdate=2017-01-01&enddate=2017-10-01&sortby=mostrecent&page=1&perpage=200')
response = TextResponse(r.url, body=r.text, encoding='utf-8')
print response.body
# Out:
# {
#   "hits": [
#     {
#       "_id": "10273591",
#       "_index": "stdotcom_v9",
#       "_score": null,
#       "_type": "wp_posts",
#       "fields": {
#         "ID": 10273591,
#         "nwshowcaseLabel": null,
#         "publish_date": "2017-01-24T18:11:02+00:00",
#         "st_authors": [
#           "The Associated Press"
#         ],
#         "st_mediaicon": "none",
#         "st_primary_section_name": "Nation &amp; World",
#         "summary": "",
#         "teaser_image_url": null,
#         "title": "Minnesota Gov. Mark Dayton says he will finish his term despite being diagnosed with prostate cancer",
#         "type": "post",
#         "url": "http://www.seattletimes.com/nation-world/minnesota-gov-mark-dayton-says-he-will-finish-his-term-despite-being-diagnosed-with-prostate-cancer/"
#       },
#       "sort": [
#         1485281462000
#       ]
#     },
#     {
#       "_id": "10273588",
#       "_index": "stdotcom_v9",
#       "_score": null,
# ...

# %%
articles_json = json.loads(response.body)
for hits in articles_json['hits']:
    print hits['fields']['url']
# Out:
# http://www.seattletimes.com/nation-world/minnesota-gov-mark-dayton-says-he-will-finish-his-term-despite-being-diagnosed-with-prostate-cancer/
# http://www.seattletimes.com/nation-world/minnesota-gov-mark-dayton-says-he-has-prostate-cancer-and-will-discuss-treatment-options-with-doctors-next-week/
# http://www.seattletimes.com/business/amazon/amazons-content-strategy-yields-best-picture-nomination-at-oscars/
# http://www.seattletimes.com/business/economy/the-robot-elephant-in-the-room-with-the-auto-titans/
# http://www.seattletimes.com/nation-world/judges-rules-in-favor-of-university-in-open-records-case/
# http://www.seattletimes.com/nation-world/prosecutors-girl-kept-in-basement-prison-with-chains-cuffs/
# http://www.seattletimes.com/business/trump-bans-epa-employees-from-providing-updates-on-social-media-or-to-reporters-bars-awarding-new-contracts-or-grants/
# http://www.seattletimes.com/nation-world/police-fatally-shoot-man-armed-with-knives-after-standoff/
# ...

# %%
r = requests.get('http://www.seattletimes.com/nation-world/ex-mayor-pleads-guilty-in-wild-west-museum-artifacts-case/')
response = TextResponse(r.url, body=r.text, encoding='utf-8')
print response.body
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 10]>      <html class="no-js lt-ie10 no-support" lang="en-US" itemscope itemtype="http://schema.org/Article" > <![endif]-->
# <!--[if gt IE 9]><!-->  <html class="no-js"         lang="en-US" itemscope itemtype="http://schema.org/Article" > <!--<![endif]-->
# <head>
#
#   <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/>
# ...
